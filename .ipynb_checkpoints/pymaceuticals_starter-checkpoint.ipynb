# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from scipy.stats import sem

# Study data files
mouse_metadata_path = "Mouse_metadata.csv"
study_results_path = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_results = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')


# Display the data table for preview
mouse_results
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_count = mouse_results['Mouse ID'].nunique()
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mouse = mouse_results[mouse_results.duplicated(['Mouse ID', 'Timepoint'])] 
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse = mouse_results.loc[mouse_results['Mouse ID'] == 'g989']
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_results = mouse_results.drop_duplicates(subset=['Mouse ID', 'Timepoint'], keep=False)
clean_results
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_count = clean_results['Mouse ID'].nunique()
clean_mouse_count
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
grouped_summary = clean_results.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)':
                [np.mean, np.median, np.var, np.std, st.sem]})
grouped_summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.458254  50.854632  44.053659  6.637293  0.540135
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

drug_data = pd.DataFrame(combined_df.groupby(["Drug Regimen"]).count()).reset_index()
drugs_df = drug_data[["Drug Regimen", "Mouse ID"]]
drugs_df = drugs_df.set_index("Drug Regimen")

drugs_df.plot(kind="bar", figsize=(10,3))

plt.title("Drug Treatment Count")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
drug_list = summary_df.index.tolist()
drug_list
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
drug_count = (combined_df.groupby(["Drug Regimen"])["Age_months"].count()).tolist()
drug_count
# Out:
# [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

# %%
x_axis = np.arange(len(drug_count))
x_axis = drug_list
plt.figure(figsize=(11,4))
plt.bar(x_axis, drug_count, color='b', alpha=0.5, align="center")

plt.title("Drug Treatment Count")
plt.xlabel("Drug Regimen")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
plt.clf()
plt.cla()
plt.close()

gender_df = pd.DataFrame(combined_df.groupby(["Sex"]).count()).reset_index()
gender_df.head()
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       935           935         935         935        935
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 935               935
# 1                 958               958

# %%
gender_df = gender_df[["Sex","Mouse ID"]]
gender_df.head()
# Out:
#       Sex  Mouse ID
# 0  Female       935
# 1    Male       958

# %%
plt.figure(figsize=(12,6))
ax1 = plt.subplot(121, aspect="equal")
gender_df.plot(kind="pie", y = "Mouse ID", ax=ax1, autopct='%1.1f%%',
              startangle=190, shadow=True, labels=gender_df["Sex"], legend = False, fontsize=14)

plt.title("Male & Female Mice Percentage")
plt.xlabel("")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = (combined_df.groupby(["Sex"])["Age_months"].count()).tolist()
gender_count
# Out:
# [935, 958]

# %%
labels = ["Females", "Males"]
colors = ["blue", "yellow"]
explode = (0.1, 0)
plt.pie(gender_count, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=160)
plt.axis("equal")
# Out:
# (-1.168554778187085,
#  1.1046347624021708,
#  -1.2267182048220846,
#  1.1096662105117718)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
reduced_drug_groups = clean_results.loc[clean_results['Drug Regimen'].isin(['Capomulin', 'Ramicane', 
                                                                                  'Infubinol', 'Ceftamin'])]
reduced_drug_groups
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 1        k403     Ramicane    Male          21          16          5
# 2        k403     Ramicane    Male          21          16         10
# 3        k403     Ramicane    Male          21          16         15
# 4        k403     Ramicane    Male          21          16         20
# ...       ...          ...     ...         ...         ...        ...
# 1868     z581    Infubinol  Female          24          25         25
# 1869     z581    Infubinol  Female          24          25         30
# 1870     z581    Infubinol  Female          24          25         35
# 1871     z581    Infubinol  Female          24          25         40
# 1872     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Start by getting the last (greatest) timepoint for each mouse
reduced_dg_timepoint = reduced_drug_groups.groupby(['Mouse ID'])['Timepoint'].max()
reduced_dg_timepoint
# Out:
# Mouse ID
# a203    45
# a251    45
# a275    45
# a411    45
# a444    45
#         ..
# y769    45
# y793    45
# y865    45
# z578    45
# z581    45
# Name: Timepoint, Length: 100, dtype: int64

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_dg_df = pd.merge(reduced_dg_timepoint, reduced_drug_groups, on=['Timepoint', 'Mouse ID'], 
                        how='inner')

merged_dg_df
# Out:
#     Timepoint Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  \
# 0          45     a203    Infubinol  Female          20          23
# 1          45     a251    Infubinol  Female          21          25
# 2          45     a275     Ceftamin  Female          20          28
# 3          45     a411     Ramicane    Male           3          22
# 4          45     a444     Ramicane  Female          10          25
# ..        ...      ...          ...     ...         ...         ...
# 95         45     y769     Ceftamin  Female           6          27
# 96         45     y793    Capomulin    Male          17          17
# 97         45     y865     Ceftamin    Male          23          26
# 98         45     z578     Ramicane    Male          11          16
# 99         45     z581    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = merged_dg_df['Tumor Volume (mm3)'].quantile([0.25,0.5,0.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
capomulin = merged_dg_df.loc[merged_dg_df['Drug Regimen'] == 'Capomulin']['Tumor Volume (mm3)']    
ramicane = merged_dg_df.loc[merged_dg_df['Drug Regimen'] == 'Ramicane']['Tumor Volume (mm3)']
infubinol = merged_dg_df.loc[merged_dg_df['Drug Regimen'] == 'Infubinol']['Tumor Volume (mm3)']
ceftamin = merged_dg_df.loc[merged_dg_df['Drug Regimen'] == 'Ceftamin']['Tumor Volume (mm3)']
  
    
    # add subset 
tumor_vol_data = [capomulin, ramicane, infubinol, ceftamin]     
    
    # Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# Values below 3.0739668737500097 could be outliers.
# Values above 94.04403868374999 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title('Capomulin')
ax1.set_ylabel('Final Tumor Volume')
ax1.boxplot(capomulin)
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('Ramicane')
ax1.set_ylabel('Final Tumor Volume')
ax1.boxplot(ramicane)
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('Infubinol')
ax1.set_ylabel('Final Tumor Volume')
ax1.boxplot(capomulin)
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('Ceftamin')
ax1.set_ylabel('Final Tumor Volume')
ax1.boxplot(capomulin)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
y769_tumor = clean_results.loc[clean_results['Mouse ID'] == 'y793']['Tumor Volume (mm3)'] 
y769_time = clean_results.loc[clean_results['Mouse ID'] == 'y793']['Timepoint']
plt.plot(y769_time, y769_tumor, color="blue", label="Tumor Size with Capomulin Treatment" )
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
x_values = clean_results[clean_results['Drug Regimen'] == 'Capomulin']['Weight (g)']   
y_values = clean_results[clean_results['Drug Regimen'] == 'Capomulin']['Tumor Volume (mm3)']  
plt.scatter(x_values,y_values)
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = round(st.pearsonr(x_values, y_values)[0],2)
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
print(f"The r-squared is: {rvalue**2}")
print(f"The correlation coefficient between weight and tumor volume is {correlation}")
plt.show()
# Out:
# The r-squared is: 0.2763600223455911
# The correlation coefficient between weight and tumor volume is 0.53
